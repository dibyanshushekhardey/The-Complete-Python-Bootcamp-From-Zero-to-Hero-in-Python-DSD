# %%
my_list = [1, 2, 3]

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %%
type(my_list)
# Out:
# list

# %%
class Dog():
    
    def __init__(self, breed, name, spots):
        # Attributes
        # We take in the argument
        # Assign it usingh self.attribute_name
        self.breed = breed
        self.name = name
        
        # Expect boolean True/False
        self.spots = spots

# %%
my_sample = Sample()   # instance of class

# %%
type(my_sample)
# Out:
# __main__.Sample

# %%
my_dog = Dog(breed = 'lab', name='Sammy', spots='NO SPOTS')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.breed
# Out:
# 'lab'

# %%
my_dog.name
# Out:
# 'Sammy'

# %%
my_dog.spots
# Out:
# 'NO SPOTS'

# %% [markdown]
# ## Class attributes and methods

# %%
class Dog():
    
    # Class object attribute
    # same for any instance of a class
    species = 'mammal'
    
    
    def __init__(self, breed, name): #, spots
        # Attributes
        # We take in the argument
        # Assign it usingh self.attribute_name
        self.breed = breed
        self.name = name
        
        # Expect boolean True/False
        #self.spots = spots
        
    # operations/Actions --> Methods
    def bark(self, number):
        print('Woof My name is {} and the number is {}'.format(self.name, number ))

# %%
my_dog=Dog(breed='lab', name='Sam')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.species
# Out:
# 'mammal'

# %%
my_dog = Dog('lab', 'Frankie')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.name
# Out:
# 'Frankie'

# %%
my_dog.bark    # method that is bound to the object at the omputers memmory address
# Out:
# <bound method Dog.bark of <__main__.Dog object at 0x107eb29d0>>

# %%
my_dog.bark()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 my_dog.bark()
#
# TypeError: Dog.bark() missing 1 required positional argument: 'number'

# %%
my_dog.bark(10)
# Out:
# Woof My name is Frankie and the number is 10

# %%
class Circle():
    
    # class object attribute
    pi = 3.14
    
    def __init__(self, radius = 1):
        self.radius = radius
        self.area = self.pi * (radius**2)
        
    # method
    def get_circumference(self):
        return self.radius * self.pi * 2

# %%
my_circle = Circle(30) # Overrides the radius in the __init__ method

# %%
my_circle.get_circumference()
# Out:
# 188.4

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle.radius
# Out:
# 30

# %%
my_circle.area
# Out:
# 2826.0

# %% [markdown]
# ## Inheritance and polymorphism

# %%
class Animal():
    
    def __init__(self):
        print('ANIMAL CREATED')
    
    def who_am_i(self):
        print("I am an animal")
    
    def eat(self):
        print("I am eating")

# %%
myanimal = Animal()
# Out:
# ANIMAL CREATED

# %%
myanimal.eat()
# Out:
# I am eating

# %%
myanimal.who_am_i()
# Out:
# I am an animal

# %%
class Dog(Animal):    # derived class
    
    def __init__(self):
        Animal.__init__(self)
        print('Dog created')
    
    def bark(self):
        print('WOOF!')

# %%
mydog = Dog()
# Out:
# ANIMAL CREATED
# Dog created

# %%
mydog.eat()
# Out:
# I am eating

# %%
mydog.who_am_i()   # derived class has a new method that overrides the parent class
# Out:
# I am an animal

# %%
mydog.bark()
# Out:
# WOOF!

# %% [markdown]
# ## polymoprphism

# %%
class Dog():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + ' says Woof!'

# %%
class Cat():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + ' says meow!'

# %%
niko = Dog('niko')
felix = Cat('felix')

# %%
print(niko.speak())
# Out:
# niko says Woof!

# %%
print(felix.speak())
# Out:
# felix says meow!

# %%
for pet in [niko, felix]:
    print(type(pet))
    print(type(pet.speak()))
    print(pet.speak())
# Out:
# <class '__main__.Dog'>
# <class 'str'>
# niko says Woof!
# <class '__main__.Cat'>
# <class 'str'>
# felix says meow!

# %%
def pet_speak(pet):
    print(pet.speak())

# %%
pet_speak(niko)
# Out:
# niko says Woof!

# %%
pet_speak(felix)
# Out:
# felix says meow!

# %%
class Animal():
    def __init__(self, name):
        self.name = name
        
    def speak(self):
        raise NotImplementedError("Subclass must implement this abstract method")

# %%
myanimal = Animal('fred')

# %%
myanimal.speak()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 myanimal.speak()
#
# Cell In[125], line 6, in Animal.speak(self)
#       5 def speak(self):
# ----> 6     raise NotImplementedError("Subclass must implement this abstract method")
#
# NotImplementedError: Subclass must implement this abstract method

# %%
class Dog(Animal):
    def speak(self):
        return self.name + ' says woof!'

# %%
class Cat(Animal):
    def speak(self):
        return self.name + ' says meow!'

# %%
fido = Dog("Fido")

# %%
isis = Cat("Isis")

# %% [markdown]
# ## Special methods

# %%
mylist = [1, 2, 3]

# %%
len(mylist)
# Out:
# 3

# %%
class Sample():
    pass

# %%
mysample = Sample()

# %%
print(mysample)

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Book():
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
        
    def __str__(self):
        return f"{self.title} by {self.author}"
    
    def __len__(self):
        return self.pages
    
    def __del__(self):
        print("A book object has been deleted")

# %%
b = Book('Python rocks', 'Jose', 200)

# %%
print(b)
# Out:
# Python rocks by Jose

# %%
len(b)
# Out:
# 200

# %%
del b
# Out:
# A book object has been deleted

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %% [markdown]
# ## Extra topics

# %%
class Simple():
    
    def __init__(self, value):
        self.value = value
        
    def add_to_value(self, amount):
        self.value = self.value + amount
        print('We just added {} to your value'.format(amount))

# %%
myobj = Simple(300)

# %%
myobj.value
# Out:
# 300

# %%
myobj.add_to_value(500)
# Out:
# We just added 500 to your value
