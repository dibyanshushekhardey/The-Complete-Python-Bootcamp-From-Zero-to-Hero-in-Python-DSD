# %% [markdown]
# ## OOP Challenge official solution

# %%
class Account():
    
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
        
    def deposit(self, dep_amt):
        self.balance = self.balance + dep_amt
        print(f"Added {dep_amt} to the balance")
    
    def withdrawal(self, wd_amt):
        if self.balance >= wd_amt:
            self.balance -= wd_amt
            print("Withdrawal accepted")
        else:
            print("soory not enough funds!")
    
    def __str__(self):
        return f"Owner: {self.owner} \nBalance: {self.balance}"

# %%
a = Account("Sam", 500)

# %%
a.owner
# Out:
# 'Sam'

# %%
a.balance
# Out:
# 500

# %%
print(a)
# Out:
# Owner: Sam
# Balance: 500

# %%
a.deposit(100)
# Out:
# Added 100 to the balance

# %%
print(a)
# Out:
# Owner: Sam
# Balance: 600

# %%
a.withdrawal(600)
# Out:
# Withdrawal accepted

# %%
a.withdrawal(1)
# Out:
# soory not enough funds!

# %%
print(a)
# Out:
# Owner: Sam
# Balance: 0
