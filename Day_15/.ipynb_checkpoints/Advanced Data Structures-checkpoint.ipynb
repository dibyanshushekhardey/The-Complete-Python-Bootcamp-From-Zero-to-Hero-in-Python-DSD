# %%
# advanced numbers

# %%
# hexadecimal

# %%
hex(246)
# Out:
# '0xf6'

# %%
hex(512)
# Out:
# '0x200'

# %%
# binary

# %%
bin(1234)
# Out:
# '0b10011010010'

# %%
bin(128)
# Out:
# '0b10000000'

# %%
bin(1024)
# Out:
# '0b10000000000'

# %%
# pow

# %%
pow(3, 4)
# Out:
# 81

# %%
pow(3, 4, 5)
# Out:
# 1

# %%
# absolute

# %%
abs(-3.14)
# Out:
# 3.14

# %%
abs(3)
# Out:
# 3

# %%
round(3, 2)
# Out:
# 3

# %%
round(395, 4)
# Out:
# 395

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
round(math.pi, 2)
# Out:
# 3.14

# %%
# advanced strings

# %%
s = 'hello world'

# %%
# capitLising the first word of the string
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s
# Out:
# 'hello world'

# %%
# reassignment of the string value

# %%
s = s.upper()
s
# Out:
# 'HELLO WORLD'

# %%
s = s.lower()
s
# Out:
# 'hello world'

# %%
# location and counting

# %%
# returning the number of occurences without overlap
s.count('o')
# Out:
# 2

# %%
# to return the starting index of the first occurence
s.find('o')
# Out:
# 4

# %%
# formatting
a = s.center(20, 'z')

# %%
a
# Out:
# 'zzzzhello worldzzzzz'

# %%
len(a)
# Out:
# 20

# %%
'helllo\thi'.expandtabs()
# Out:
# 'helllo  hi'

# %%
# is check methods

# %%
s = 'hello'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.endswith('o')
# Out:
# True

# %%
# built in reg expressions

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo')

# %%
# advanced sets

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
# clear - removing all the elements from the set

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
# copy

# %%
s = {1, 2, 3}
sc = s.copy()

# %%
sc
# Out:
# {1, 2, 3}

# %%
s
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
sc
# Out:
# {1, 2, 3}

# %%
# difference

# %%
s.difference(sc)
# Out:
# {4}

# %%
# difference update

# %%
s1 = {1, 2, 3}

# %%
s2 = {1, 4, 5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
# discard

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %%
# intersection and intersection update

# %%
s1 = {1, 2, 3}

# %%
s2 = {1, 2, 4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
# isdisjoint

# %%
s1 = {1, 2}
s2 = {1, 2, 4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
# is subset
s1
# Out:
# {1, 2}

# %%
s1.issubset(s2)
# Out:
# True

# %%
# isuperset
s2.issuperset(s1)
# Out:
# True

# %%
s1.issuperset(s2)
# Out:
# False

# %%
# symmetric difference and symmetric update
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
# union

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
# update

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}

# %%
# advanced dictionaries

# %%
# dictionary comprehensions
{x:x**2 for x in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
# iteration over keysm values and items

# %%
d = {'k1':1, 'k2':2}

# %%
for k in d.keys():
    print(k)
# Out:
# k1
# k2

# %%
for v in d.values():
    print(v)
# Out:
# 1
# 2

# %%
for item in d.items():
    print(item)
# Out:
# ('k1', 1)
# ('k2', 2)

# %%
# viewing keys, values and items

# %%
key_view = d.keys()
key_view
# Out:
# dict_keys(['k1', 'k2'])

# %%
d['k3'] = 3
d
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
key_view
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
# advanced lists

# %%
list1 = [1, 2, 3]

# %%
# append
list1.append(4)
list1
# Out:
# [1, 2, 3, 4]

# %%
# count
list1.count(10)
# Out:
# 0

# %%
list1.count(2)
# Out:
# 1

# %%
# extend

# %%
x = [1, 2, 3]
x.append([4, 5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1, 2, 3]
x.extend([4, 5])
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
# index

# %%
list1.index(2)
# Out:
# 1

# %%
list1.index(12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 list1.index(12)
#
# ValueError: 12 is not in list

# %%
# insert

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
# placing an item at the referenced index

# %%
list1.insert(2, 'inserted')

# %%
list1
# Out:
# [1, 2, 'inserted', 3, 4]

# %%
# pop

# %%
ele= list1.pop(1)

# %%
ele
# Out:
# 2

# %%
# remove

# %%
list1
# Out:
# [1, 'inserted', 3, 4]

# %%
list1.remove('inserted')

# %%
list1
# Out:
# [1, 3, 4]

# %%
list2 = [1, 2, 3, 4, 3]

# %%
list2.remove(3)

# %%
list2
# Out:
# [1, 2, 4, 3]

# %%
# reverse

# %%
list2.reverse()

# %%
list2
# Out:
# [3, 4, 2, 1]

# %%
# sort

# %%
list2
# Out:
# [3, 4, 2, 1]

# %%
list2.sort()

# %%
list2
# Out:
# [1, 2, 3, 4]

# %%
list2.sort(reverse=True)

# %%
list2
# Out:
# [4, 3, 2, 1]

# %%
## Note

# %%
x = 'hello world'

# %%
y = x.upper()

# %%
y
# Out:
# 'HELLO WORLD'

# %%
x = [1, 2, 3]
y = x.copy()
y.append(4)

# %%
print(x)
# Out:
# [1, 2, 3]

# %%
print(y)
# Out:
# [1, 2, 3, 4]
