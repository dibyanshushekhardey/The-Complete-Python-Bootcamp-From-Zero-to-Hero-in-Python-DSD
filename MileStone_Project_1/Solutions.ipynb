# %%
# Solutions

# %%
from IPython.display import clear_output

def display_board(board):
    clear_output()
    print('   |   |')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |')

# %%
test_board = ['#', 'X', 'O','X', 'O','X', 'O','X', 'O', 'X']
display_board(test_board)
display_board(test_board)
# Out:
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |

# %%
# write a function that can take in a player input and assign theor marker as 'X' or 'O'. 
# think about using while loops to continualy ask until you get a correct answer

# %%
def player_input():
    
    '''
    OUTPUT: (Player 1 marker, Player 2 marker)
    '''
    marker = ''
    while marker != 'X' and marker != 'O':
        marker = input('Player 1: Chosse X or O:').upper()
        
    if marker == 'X':
        return ('X', 'O')
    else:
        return ('O', 'X')

# %%
player1_marker, player2_marker = player_input()
# Out:
# Player 1: Chosse X or O:X

# %%
player1_marker
# Out:
# 'X'

# %%
# Step 3 write a function that takes in the board list object, a marker ('X' or 'O') and a desired position (1 - 9) and assigns it to the board

# %%
def place_marker(board, marker, position):
    board[position] = marker

# %%
test_board
# Out:
# ['#', 'X', 'O', 'X', 'O', 'X', 'O', 'X', 'O', 'X']

# %%
place_marker(test_board, '$', 8)
display_board(test_board)
# Out:
#    |   |
#  X | $ | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |

# %%
# Step 4: write a function that takes in a board and a amrk (X or O) and then checks to see if that mark has won

# %%
def win_check(board, mark):
    # win tic tac toe?
    # all rows and check to see if they all share the same marker?
    return (
    (board[1] == board[2] == board[3] == mark) or # row 1
    (board[4] == board[5] == board[6] == mark) or # row 2
    (board[9] == board[8] == board[9] == mark) or # row 3
    (board[1] == board[4] == board[7] == mark) or # col 1
    (board[2] == board[5] == board[8] == mark) or # col 2
    (board[3] == board[6] == board[9] == mark) or # col 3
    (board[1] == board[5] == board[9] == mark) or # diag 1 
    (board[7] == board[5] == board[3] == mark) # diag 2
    )
    # all columns and check to see if they all share the same marker?
    # 2 diagonals, check to see the match

# %%
display_board(test_board)
win_check(test_board, 'X')
# Out:
#    |   |
#  X | $ | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |
# True

# %%
# step 5 write a function that uses the random module
# to randomly decide which player goes first
# you may want to lookup random.randint()
# return a string of which player weent first

# %%
import random

def choose_first():
    flip = random.randint(0, 1)
    
    if flip == 0:
        return 'Player 1'
    else:
        return 'Player 2'

# %%
# Step 6 write a function that returns a bolean indicating whether a space on the board is freely available

# %%
def space_check(board, position):
    return board[position] == ' '

# %%
# step 7: Wriet a function that checks if the board
# is full and returns a boolean value.
# true of full, false otherwise

# %%
def full_board_check(board):
    for i in range(1, 10):
        if space_check(board, i):
            return False
    return True

# %%
# Step 8 write a function that asks for a player's next postion
# As number 1-9 and then uses the function from step 6 to check if
# it is a free position
# if it is then return the postion for later use

# %%
def player_choice(board):
    position = 0
    while position not in [1, 2, 3, 4, 5, 6, 7, 8, 9] or not space_check(board, position):
        position = int(input("Choose a position (1-9): "))
    return position

# %%
# Step 9 write a function that asks the player if they want to play
# again and returns a boolean True if they do want to play again

# %%
def replay():
    choice = input("Play again? Enter Yes or No")
    return choice == "Yes"

# %%
# While loop to keep running the game
print("Welcome to Tic Tac Toe")

while True:
    # play the game
    
    ## set everything up(board, who's first, choose markers, X, O)
    the_board = [' ']*10
    player_1_marker, player_2_marker = player_input()
    
    turn = choose_first()
    print(turn + ' will go first')
    
    play_game = input('Ready to play? y or n? ')
    
    
    if play_game == 'y':
        game_on = True
    else:
        game_on = False
    ## game play
    while game_on:
        if turn == 'Player 1':
            # show the board
            display_board(the_board)
            # choose a postion
            position = player_choice(the_board)
            # place the m,arker on the postion
            place_marker(the_board, player_1_marker, position)
            # check if they won
            if win_check(the_board, player_1_marker):
                display_board(the_board)
                print('Player 1 has won!')
                game_on = False
            else:
                if full_board_check(the_board):
                    display_board(the_board)
                    print('TIE GAME!')
                    break
                else:
                    turn = 'Player 2'
                
        # or check if there is a tie
        
        # no tie and no win? then next players' turn
        else:
            # show the board
            display_board(the_board)
            # choose a postion
            position = player_choice(the_board)
            # place the m,arker on the postion
            place_marker(the_board, player_2_marker, position)
            # check if they won
            if win_check(the_board, player_2_marker):
                display_board(the_board)
                print('Player 2 has won!')
                game_on = False
            else:
                if full_board_check(the_board):
                    display_board(the_board)
                    print('TIE GAME!')
                    break
                else:
                    turn = 'Player 1'
    

    
    if not replay():
        break

# break out of the while loop on replay()
# Out:
#    |   |
#  O |   | X
#    |   |
# -----------
#    |   |
#  X | X | O
#    |   |
# -----------
#    |   |
#  X | O |
#    |   |
# Player 1 has won!
# Play again? Enter Yes or No1
