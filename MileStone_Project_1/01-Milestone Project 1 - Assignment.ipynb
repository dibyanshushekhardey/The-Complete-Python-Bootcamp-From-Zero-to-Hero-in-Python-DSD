# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 1
# ## Congratulations on making it to your first milestone!
# You've already learned a ton and are ready to work on a real project.
#
# Your assignment: Create a Tic Tac Toe game. You are free to use any IDE you like.
#
# Here are the requirements:
#
# * 2 players should be able to play the game (both sitting at the same computer)
# * The board should be printed out every time a player makes a move
# * You should be able to accept input of the player position and then place a symbol on the board
#
# Feel free to use Google or any chatbot to help you figure anything out (but don't just ask "Tic Tac Toe in Python" otherwise you won't learn anything!) Keep in mind that this project can take anywhere between several hours to several days.
#
# There are 4 Jupyter Notebooks related to this assignment:
#
# * This Assignment Notebook
# * A "Walkthrough Steps Workbook" Notebook
# * A "Complete Walkthrough Solution" Notebook
# * An "Advanced Solution" Notebook
#
# I encourage you to just try to start the project on your own without referencing any of the notebooks. If you get stuck, check out the next lecture which is a text lecture with helpful hints and steps. If you're still stuck after that, then check out the Walkthrough Steps Workbook, which breaks up the project in steps for you to solve. Still stuck? Then check out the Complete Walkthrough Solution video for more help on approaching the project!

# %%
def display_list(game_list):
    print("Here is your current list: ")
    print(game_list)

# %%
def user_name(i):
    user_list = ['A', 'B']
    
    if i % 2 == 0:
        return user_list[0]
    else:
        return user_list[1]

# %%
def user_choice(user_name):
    choice = 'Wrong'
    if user_name == 'A':
        return 'X'
    elif user_name == 'B':
        return 'O'

# %%
def choose_position(user):
    choice = 'Wrong'
    range_list = [str(i) for i in range(0, 9)]
    
    while choice not in range_list:
        choice = input(f"User {user}, Please enter your position: ")
        
        if choice not in range_list:
            print(f"User {user}, Choose a digit from the following list")
            print(range_list)
    return int(choice)

# %%
def check_symbol(game_list, position):
    if game_list[position] == 'X' or game_list[position] == 'O':
        return False
    else:
        return True

# %%
def replacement_choice(game_list, user_choice, user_position):
    game_list[user_position] = user_choice
    return game_list

# %%
game_list = ['-', '-', '-','-', '-', '-','-', '-', '-' ]
display_list(game_list)
count = 0
while count < len(game_list):
    user = user_name(count)
    choice = user_choice(user)
    position = choose_position(user)
    if game_list[position] != '-':
        print(f"Sorry, wrong choice as {position} is already occupied")
    else:
        game_list = replacement_choice(game_list, choice, position)
        display_list(game_list)
    count += 1
# Out:
# Here is your current list:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-']
# User A, Please enter your position: 0
# Here is your current list:
# ['X', '-', '-', '-', '-', '-', '-', '-', '-']
# User B, Please enter your position: 2
# Here is your current list:
# ['X', '-', 'O', '-', '-', '-', '-', '-', '-']
# User A, Please enter your position: 3
# Here is your current list:
# ['X', '-', 'O', 'X', '-', '-', '-', '-', '-']
# User B, Please enter your position: 1
# Here is your current list:
# ['X', 'O', 'O', 'X', '-', '-', '-', '-', '-']
# User A, Please enter your position: 4
# Here is your current list:
# ['X', 'O', 'O', 'X', 'X', '-', '-', '-', '-']
# User B, Please enter your position: 7
# Here is your current list:
# ['X', 'O', 'O', 'X', 'X', '-', '-', 'O', '-']
# User A, Please enter your position: 8
# Here is your current list:
# ['X', 'O', 'O', 'X', 'X', '-', '-', 'O', 'X']
# User B, Please enter your position: 6
# Here is your current list:
# ...

# %%
X_list = []
O_list = []
other_list = []

for i in range(len(game_list)):
    if game_list[i] == 'X':
        X_list.append(i)
    elif game_list[i] == 'O':
        O_list.append(i)
    else:
        o_list.append(i)

A_result = ''.join(map(str, X_list))

if '012' or '345' or '678' or '036' or '047' or '258' or '048' or '147' in A_result:
    print("A wins")
elif '012' or '345' or '678' or '036' or '047' or '258' or '048' or '147' in B_result:
    print("B wins")
else:
    print("Draw")
# Out:
# A wins

# %% [markdown]
# There are parts of this that will be a struggle...and that is good! I have complete faith that if you have made it this far through the course you have all the tools and knowledge to tackle this project. Remember, it's totally open book, so take your time, do a little research, and remember:
#
# ## HAVE FUN!
