# %%
# Displaying info

# %%
print([1,2,3])
# Out:
# [1, 2, 3]

# %%
print([1,2,3])
print([4,5,6])
print([7,8,9])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
def display(row1, row2, row3):
    print(row1)
    print(row2)
    print(row3)

# %%
example_row = [1, 2, 3]

display(example_row, example_row, example_row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = [' ',  ' ',  ' ']
row2 = [' ',  ' ',  ' ']
row3 = [' ',  ' ',  ' ']

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1, row2, row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
# Accepting user input

# %%
input("Please enter a value: ")
# Out:
# Please enter a value: 2
# '2'

# %%
result = input("Please enter a value: ")
# Out:
# Please enter a value: 2

# %%
result
# Out:
# '2'

# %%
type(result)
# Out:
# str

# %%
result = input('Enter value: ')
# Out:
# Enter value: 2

# %%
result_int = int(result)

# %%
type(result)
# Out:
# str

# %%
type(result_int)
# Out:
# int

# %%
type(2.3)
# Out:
# float

# %%
float('3.14')
# Out:
# 3.14

# %%
position_index = int(input("Choose an index position: "))
# Out:
# Choose an index position: 2

# %%
type(position_index)
# Out:
# int

# %%
row2[position_index]
# Out:
# ' '

# %%
position_index = int(input("Choose an index position: "))
# Out:
# Choose an index position: two
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 position_index = int(input("Choose an index position: "))
#
# ValueError: invalid literal for int() with base 10: 'two'

# %%
result = input("Enter a number: ")
# Out:
# Enter a number: 2

# %%
2 + 2
# Out:
# 4

# %%
input('Enter number: ')
# Out:
# Enter number: 2
# '2'

# %%
20 + 20
# Out:
# 40

# %%
# validating user input

# %%
def user_choice():
    
    choice = 'WRONG'
    
    while choice.isdigit() == False:
        choice = input("Please enter a number (0-10): ")
        
        if choice.isdigit() == False:
            print("soory that is not a digit!")
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): dhjgsfk
# soory that is not a digit!
# Please enter a number (0-10): hdg
# soory that is not a digit!
# Please enter a number (0-10): 9
# 9

# %%
some_value = '100'

# %%
some_value.isdigit()
# Out:
# True

# %%
int(some_value)
# Out:
# 100

# %%
result = 'WRONG VALUE'

# %%
acceptable_value = [0, 1, 2]

# %%
result in acceptable_value
# Out:
# False

# %%
result not in acceptable_value
# Out:
# True

# %%
def user_choice():
    
    # Variables
    
    #Initial
    choice = 'WRONG'
    acceptable_range = range(0, 10)
    within_range = False
    
    # Two conditions to check
    # digit or within_range == False
    while choice.isdigit() == False or within_range == False:
        
        
        choice = input("Please enter a number (0-10): ")
        
        # Digit check
        if choice.isdigit() == False:
            print("soory that is not a digit!")
            
        # range check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
            else:
                print("Sorry you are out of acceptable range (0-10)")
                within_range = False
                
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): 100
# Sorry you are out of acceptable range (0-10)
# Please enter a number (0-10): dshgkf
# soory that is not a digit!
# Please enter a number (0-10): 9
# 9

# %%
# Simple user interaction

# %%
game_list = [0, 1, 2]

# %%
def display_game(game_list):
    print("Here is the current list: ")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list:
# [0, 1, 2]

# %%
def position_choice():
    
    choice = 'wrong'
    
    while choice not in ['0', '1', '2']:
        choice = input('Pick a position (0, 1, 2): ')
        
        if choice not in ['0', '1', '2']:
            print("Sorry, invalid choice")
    return int(choice)

# %%
position_choice()
# Out:
# Pick a position (0, 1, 2): two
# Sorry, invalid choice
# Pick a position (0, 1, 2): 24
# Sorry, invalid choice
# Pick a position (0, 1, 2): 1
# 1

# %%
def replacement_choice(game_list, position):
    user_placement = input("Type a string to place at position: ")
    
    game_list[position] = user_placement
    
    return game_list

# %%
replacement_choice(game_list, 1)
# Out:
# Type a string to place at position: test
# [0, 'test', 2]

# %%
def gameon_choice():
    choice = 'Wrong'
    
    while choice not in ['Y', 'N']:
        choice = input("Keep playing? (Y or N) ")
        
        if choice not in ['Y', 'N']:
            print("Soory, I do not understand, please choose Y or N")
    if choice == "Y":
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Keep playing? (Y or N) Y
# True

# %%
game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)
    
    position = position_choice()
    
    game_list = replacement_choice(game_list, position)
    
    display_game(game_list)
    
    game_on = gameon_choice()
# Out:
# Here is the current list:
# [0, 1, 2]
# Pick a position (0, 1, 2): two
# Sorry, invalid choice
# Pick a position (0, 1, 2): 1
# Type a string to place at position: my choice
# Here is the current list:
# [0, 'my choice', 2]
# Keep playing? (Y or N) Y
# Here is the current list:
# [0, 'my choice', 2]
# Pick a position (0, 1, 2): 0
# Type a string to place at position: test
# Here is the current list:
# ['test', 'my choice', 2]
# Keep playing? (Y or N) MN
# Soory, I do not understand, please choose Y or N
# Keep playing? (Y or N) N
