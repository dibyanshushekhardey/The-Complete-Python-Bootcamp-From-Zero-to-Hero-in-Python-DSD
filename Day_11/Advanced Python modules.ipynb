# %%
## Python collections

# %%
from collections import Counter

# %%
mylist = [1, 1, 1, 1, 1, 2, 3, 3, 3, 2, 2, 2, 3, 3]

# %%
Counter(mylist)
# Out:
# Counter({1: 5, 3: 5, 2: 4})

# %%
mylist = ['a', 'a', 10, 10, 10]

# %%
Counter(mylist)
# Out:
# Counter({10: 3, 'a': 2})

# %%
Counter('adhskjfgksgfkkjsdgfjsfk')
# Out:
# Counter({'k': 5, 's': 4, 'f': 4, 'j': 3, 'g': 3, 'd': 2, 'a': 1, 'h': 1})

# %%
sentence = "How many times does each word show up in this sentence"

# %%
Counter(sentence.lower().split())
# Out:
# Counter({'how': 1,
#          'many': 1,
#          'times': 1,
#          'does': 1,
#          'each': 1,
#          'word': 1,
#          'show': 1,
#          'up': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1})

# %%
letters = 'gdfhjagfdkfshfghjsdfjkejf'

# %%
c = Counter(letters)

# %%
c
# Out:
# Counter({'f': 6,
#          'j': 4,
#          'g': 3,
#          'd': 3,
#          'h': 3,
#          'k': 2,
#          's': 2,
#          'a': 1,
#          'e': 1})

# %%
c.most_common(3)
# Out:
# [('f', 6), ('j', 4), ('g', 3)]

# %%
c
# Out:
# Counter({'f': 6,
#          'j': 4,
#          'g': 3,
#          'd': 3,
#          'h': 3,
#          'k': 2,
#          's': 2,
#          'a': 1,
#          'e': 1})

# %%
list(c)
# Out:
# ['g', 'd', 'f', 'h', 'j', 'a', 'k', 's', 'e']

# %%
from collections import defaultdict

# %%
d = {'a':10}

# %%
d
# Out:
# {'a': 10}

# %%
d['a']
# Out:
# 10

# %%
d['Wrong']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 d['Wrong']
#
# KeyError: 'Wrong'

# %%
d = defaultdict(lambda: 0)

# %%
d['correct'] = 100

# %%
d['correct']
# Out:
# 100

# %%
d['wrong_key']
# Out:
# 0

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>, {'correct': 100, 'wrong_key': 0})

# %%
mytuple = (10, 20, 30)

# %%
mytuple[0]
# Out:
# 10

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Dog', ['age', 'breed', 'name'])

# %%
Dog
# Out:
# __main__.Dog

# %%
sammy = Dog(age=5, breed='Husky', name='Sam')

# %%
type(sammy)
# Out:
# __main__.Dog

# %%
sammy
# Out:
# Dog(age=5, breed='Husky', name='Sam')

# %%
sammy.age
# Out:
# 5

# %%
sammy.breed
# Out:
# 'Husky'

# %%
sammy.name
# Out:
# 'Sam'

# %%
sammy[0]
# Out:
# 5

# %%
# opening and reading files in folder in python

# %%
pwd
# Out:
# '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11'

# %%
f = open('practice.txt', 'w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11'

# %%
os.listdir()
# Out:
# ['Advanced Python modules.ipynb', 'practice.txt', '.ipynb_checkpoints']

# %%
os.listdir()
# Out:
# ['Advanced Python modules.ipynb', 'practice.txt', '.ipynb_checkpoints']

# %%
import shutil

# %%
os.listdir('/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/')
# Out:
# ['Day_3',
#  'Day_4',
#  'MileStone_Project_2',
#  'Day_5',
#  'Day_2',
#  '.DS_Store',
#  'Day_10',
#  'Day_11',
#  'README.md',
#  'MileStone_Project_1',
#  'Day_7',
#  'Day_9',
#  'Day_8',
#  'Day_6',
#  '.ipynb_checkpoints',
#  '.git']

# %%
shutil.move('practice.txt','/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_10' )
# Out:
# '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_10/practice.txt'

# %%
os.getcwd()
# Out:
# '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11'

# %%
os.listdir()
# Out:
# ['Advanced Python modules.ipynb', '.ipynb_checkpoints']

# %%
os.listdir('/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_10/')
# Out:
# ['Generators.ipynb',
#  'practice.txt',
#  '.ipynb_checkpoints',
#  '02-Iterators and Generators Homework.ipynb']

# %%
f = open('practice1.txt', 'w+')
f.write('This is again a test string')
f.close()

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['Advanced Python modules.ipynb', 'practice1.txt', '.ipynb_checkpoints']

# %%
send2trash.send2trash('practice1.txt')

# %%
os.listdir()
# Out:
# ['Advanced Python modules.ipynb', '.ipynb_checkpoints']

# %%
os.walk
# Out:
# <function os.walk(top, topdown=True, onerror=None, followlinks=False)>

# %%
os.getcwd()
# Out:
# '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11'

# %%
filepath = '/Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11/Example_top_level'

# %%
for folder, sub_folders, files in os.walk(filepath):
    print(f"Currently looking at {folder}")
    print('\n')
    print("The subfolders are:")
    for sub_fold in sub_folders:
        print(f"Subfolder: {sub_fold}")
        
    print("\n")
    print("the files are:")
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently looking at /Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11/Example_top_level
#
#
# The subfolders are:
# Subfolder: Mid_example_2
# Subfolder: .ipynb_checkpoints
# Subfolder: Mid_example_1
#
#
# the files are:
#
#
# Currently looking at /Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11/Example_top_level/Mid_example_2
#
#
# The subfolders are:
#
#
# the files are:
#
#
# Currently looking at /Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11/Example_top_level/.ipynb_checkpoints
#
#
# The subfolders are:
#
#
# the files are:
#
#
# Currently looking at /Users/dibyanshu/Downloads/The-Complete-Python-Bootcamp-From-Zero-to-Hero-in-Python-DSD/Day_11/Example_top_level/Mid_example_1
#
#
# The subfolders are:
#
#
# the files are:

# %%
# date time module

# %%
import datetime

# %%
mytime = datetime.time(2, 20)

# %%
mytime.minute
# Out:
# 20

# %%
mytime.hour
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:20:00

# %%
mytime = datetime.time(2)

# %%
print(mytime)
# Out:
# 02:00:00

# %%
mytime.microsecond
# Out:
# 0

# %%
mytime = datetime.time(13, 20, 1, 20)

# %%
print(mytime)
# Out:
# 13:20:01.000020

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2026-02-12

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 2

# %%
today.day
# Out:
# 12

# %%
today.ctime()
# Out:
# 'Thu Feb 12 00:00:00 2026'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2021, 10, 3, 14, 20, 45, 90)

# %%
print(mydatetime)
# Out:
# 2021-10-03 14:20:45.000090

# %%
mydatetime = mydatetime.replace(year=2025)

# %%
print(mydatetime)
# Out:
# 2025-10-03 14:20:45.000090

# %%
# date

# %%
from datetime import date

# %%
date1 = date(2021, 11, 3)

# %%
date2 = date(2020, 11, 1)

# %%
result = date1 - date2

# %%
type(result)
# Out:
# datetime.timedelta

# %%
result.days
# Out:
# 367

# %%
datetime1 = datetime(2021, 11, 2, 22, 0)

# %%
datetime2 = datetime(2020, 11, 2, 12, 0)

# %%
datetime1 - datetime2
# Out:
# datetime.timedelta(days=365, seconds=36000)

# %%
36000/60/60
# Out:
# 10.0

# %%
mydiff = datetime1 - datetime2

# %%
mydiff.total_seconds()
# Out:
# 31572000.0

# %%
# math and random modules

# %%
import math

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/math.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
value = 4.35

# %%
math.floor(value)
# Out:
# 4

# %%
math.ceil(value)
# Out:
# 5

# %%
round(4.35)
# Out:
# 4

# %%
round(4.5)
# Out:
# 4

# %%
round(5.5)
# Out:
# 6

# %%
math.pi
# Out:
# 3.141592653589793

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
# numpy
